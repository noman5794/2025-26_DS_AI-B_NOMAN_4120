# %% [markdown]
# <a href="https://colab.research.google.com/github/noman5794/2025-26_DS_AI-B_NOMAN_4120/blob/main/DictionaryOperations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Dictionary creation
d = {"name": "Alex", "age": 20, "city": "Delhi"}

# Display dictionary
print("Initial dictionary:", d)

# Access value using key
print("Name:", d["name"])

# Add new key-value pair
d["course"] = "Python"
print("After adding new item:", d)

# Update value
d["age"] = 21
print("After updating age:", d)

# Remove item using pop()
d.pop("city")
print("After pop:", d)

# Remove last inserted item
d.popitem()
print("After popitem:", d)

# Get value safely (no error if key not present)
print("Phone:", d.get("phone", "Not Found"))

# Keys, values, items
print("Keys:", d.keys())
print("Values:", d.values())
print("Items:", d.items())

# Length of dictionary
print("Length:", len(d))

# Membership (checks key)
print("Is 'name' in dictionary?", "name" in d)

# Traversing dictionary
print("Dictionary elements:")
for key, value in d.items():
    print(key, ":", value)

# Clear dictionary
d.clear()
print("After clear:", d)
# Out:
# Initial dictionary: {'name': 'Alex', 'age': 20, 'city': 'Delhi'}
# Name: Alex
# After adding new item: {'name': 'Alex', 'age': 20, 'city': 'Delhi', 'course': 'Python'}
# After updating age: {'name': 'Alex', 'age': 21, 'city': 'Delhi', 'course': 'Python'}
# After pop: {'name': 'Alex', 'age': 21, 'course': 'Python'}
# After popitem: {'name': 'Alex', 'age': 21}
# Phone: Not Found
# Keys: dict_keys(['name', 'age'])
# Values: dict_values(['Alex', 21])
# Items: dict_items([('name', 'Alex'), ('age', 21)])
# Length: 2
# Is 'name' in dictionary? True
# Dictionary elements:
# name : Alex
# age : 21
# After clear: {}
