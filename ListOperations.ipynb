# %% [markdown]
# <a href="https://colab.research.google.com/github/noman5794/2025-26_DS_AI-B_NOMAN_4120/blob/main/ListOperations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# List creation
lst = [10, 20, 30, 40]

# Display list
print("Initial list:", lst)

# Append (add at end)
lst.append(50)
print("After append:", lst)

# Insert (add at position)
lst.insert(2, 25)
print("After insert:", lst)

# Remove (remove specific element)
lst.remove(20)
print("After remove:", lst)

# Pop (remove by index, default last)
lst.pop()
print("After pop:", lst)

# Index (find position)
print("Index of 30:", lst.index(30))

# Length of list
print("Length:", len(lst))

# Sort list
lst.sort()
print("After sort:", lst)

# Reverse list
lst.reverse()
print("After reverse:", lst)

# Copy list
new_list = lst.copy()
print("Copied list:", new_list)

# Clear list
lst.clear()
# Out:
# Initial list: [10, 20, 30, 40]
# After append: [10, 20, 30, 40, 50]
# After insert: [10, 20, 25, 30, 40, 50]
# After remove: [10, 25, 30, 40, 50]
# After pop: [10, 25, 30, 40]
# Index of 30: 2
# Length: 4
# After sort: [10, 25, 30, 40]
# After reverse: [40, 30, 25, 10]
# Copied list: [40, 30, 25, 10]
