# %% [markdown]
# <a href="https://colab.research.google.com/github/noman5794/2025-26_DS_AI-B_NOMAN_4120/blob/main/3_2_2026.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#write a code to create save or read a file from the local drive to perform the text operations (count no. of lines, words and charecters)

def create_file(filename, content):
    """Create or overwrite a file with given content."""
    with open(filename, "w", encoding="utf-8") as file:
        file.write(content)
    print(f"File '{filename}' created successfully.")


def read_file(filename):
    """Read the content of a file."""
    with open(filename, "r", encoding="utf-8") as file:
        return file.read()


def text_statistics(text):
    """Count lines, words, and characters."""
    lines = text.splitlines()
    words = text.split()
    characters = len(text)

    return {
        "lines": len(lines),
        "words": len(words),
        "characters": characters
    }


# -----------------------------
# Main Program
# -----------------------------
if __name__ == "__main__":
    file_name = "sample.txt"

    content = """Hello World!
This is a sample text file.
Python makes file handling easy.
"""

    # Create & save file
    create_file(file_name, content)

    # Read file
    text = read_file(file_name)

    # Perform text operations
    stats = text_statistics(text)

    print("\nText Statistics:")
    print(f"Lines      : {stats['lines']}")
    print(f"Words      : {stats['words']}")
    print(f"Characters : {stats['characters']}")
# Out:
# File 'sample.txt' created successfully.
#
# Text Statistics:
# Lines      : 3
# Words      : 13
# Characters : 74
