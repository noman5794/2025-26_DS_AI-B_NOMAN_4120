# %% [markdown]
# <a href="https://colab.research.google.com/github/noman5794/2025-26_DS_AI-B_NOMAN_4120/blob/main/SortTechniques.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Bubble sort
n = int(input("Enter number of elements: "))

arr = []

for i in range(n):
    arr.append(int(input(f"Enter element {i+1}: ")))

print("\nOriginal array:", arr)

# Bubble sort logic
for i in range(n - 1):
    for j in range(n - 1 - i):
        if arr[j] > arr[j + 1]:
            # Swap
            arr[j], arr[j + 1] = arr[j + 1], arr[j]

print("Sorted array:", arr)
# Out:
# Enter number of elements: 3
# Enter element 1: 1
# Enter element 2: 2
# Enter element 3: 3
#
# Original array: [1, 2, 3]
# Sorted array: [1, 2, 3]

# %%
# Selection sort
n = int(input("enter number of elements:"))

arr = []

for i in range(n):
    arr.append(int(input(f"enter element {i+1}:")))

print("\n Original array:", arr)

# selection sort logic
for i in range(n-1):
    min_index = i
    for j in range(i+1, n):
        if arr[j] < arr[min_index]:
            min_index = j

    # swap found min element with first element
    arr[i], arr[min_index] = arr[min_index], arr[i]

print("sorted array:", arr)
# Out:
# enter number of elements:4
# enter element 1:22
# enter element 2:3
# enter element 3:45
# enter element 4:532
#
#  Original array: [22, 3, 45, 532]
# sorted array: [3, 22, 45, 532]

# %%
# Insertion sort
n = int(input("enter number of elements: "))

arr = []

for i in range(n):
    arr.append(int(input(f"enter element {i+1}: ")))

print("\nOriginal array:", arr)

# insertion sort logic
for i in range(1, n):
    key = arr[i]          # current element
    j = i - 1

    # move elements greater than key one position ahead
    while j >= 0 and arr[j] > key:
        arr[j + 1] = arr[j]
        j -= 1

    arr[j + 1] = key      # place key at correct position

print("Sorted array:", arr)
# Out:
# enter number of elements: 3
# enter element 1: 45
# enter element 2: 76
# enter element 3: 39
#
# Original array: [45, 76, 39]
# Sorted array: [39, 45, 76]
