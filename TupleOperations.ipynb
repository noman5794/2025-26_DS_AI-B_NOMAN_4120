# %% [markdown]
# <a href="https://colab.research.google.com/github/noman5794/2025-26_DS_AI-B_NOMAN_4120/blob/main/TupleOperations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Tuple creation
t = (10, 20, 30, 40, 20)

# Display tuple
print("Tuple:", t)

# Access element
print("First element:", t[0])

# Length of tuple
print("Length:", len(t))

# Count (how many times an element appears)
print("Count of 20:", t.count(20))

# Index (position of element)
print("Index of 30:", t.index(30))

# Slicing
print("Slice (1 to 3):", t[1:4])

# Concatenation
t2 = (50, 60)
t3 = t + t2
print("After concatenation:", t3)

# Repetition
print("After repetition:", t * 2)

# Membership
print("Is 40 in tuple?", 40 in t)

# Traversing tuple
print("Tuple elements:")
for i in t:
    print(i)
# Out:
# Tuple: (10, 20, 30, 40, 20)
# First element: 10
# Length: 5
# Count of 20: 2
# Index of 30: 2
# Slice (1 to 3): (20, 30, 40)
# After concatenation: (10, 20, 30, 40, 20, 50, 60)
# After repetition: (10, 20, 30, 40, 20, 10, 20, 30, 40, 20)
# Is 40 in tuple? True
# Tuple elements:
# 10
# 20
# 30
# 40
# 20
