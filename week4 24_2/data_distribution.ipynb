# %% [markdown]
# <a href="https://colab.research.google.com/github/noman5794/2025-26_DS_AI-B_NOMAN_4120/blob/main/data_distribution.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate Data
normal_data = np.random.normal(loc=70, scale=5, size=1000)

# Right-skewed (Exponential distribution)
right_skewed = np.random.exponential(scale=10, size=1000)

# Left-skewed (Negative exponential shifted)
left_skewed = -np.random.exponential(scale=10, size=1000)

# Uniform distribution
uniform_data = np.random.uniform(low=0, high=100, size=1000)

# Plot Normal Distribution
plt.figure(figsize=(6, 5))
plt.hist(normal_data, bins=30)
plt.title("Normal Distribution")
plt.show()

# Mean & Median
print("Normal Mean:", np.mean(normal_data))
print("Normal Median:", np.median(normal_data))

print("Right-Skewed Mean:", np.mean(right_skewed))
print("Right-Skewed Median:", np.median(right_skewed))

print("Left-Skewed Mean:", np.mean(left_skewed))
print("Left-Skewed Median:", np.median(left_skewed))

print("Uniform Mean:", np.mean(uniform_data))
print("Uniform Median:", np.median(uniform_data))
# Out:
# Normal Mean: 69.8707303928168
# Normal Median: 69.79696257459172
# Right-Skewed Mean: 9.813532463851168
# Right-Skewed Median: 6.7825137986915545
# Left-Skewed Mean: -9.297782064031017
# Left-Skewed Median: -6.8490100010083905
# Uniform Mean: 50.40183614571391
# Uniform Median: 49.602261136158184

# %%
#right_skewed distribution
import numpy as np
import matplotlib.pyplot as plt

# Generate Data
right_skewed = np.random.exponential(scale=2, size=1000)

# Plot
plt.figure(figsize=(6, 5))
plt.hist(right_skewed, bins=30)
plt.title("Right-Skewed Distribution")
plt.show()

# %%
#left-skewed distribution
import numpy as np
import matplotlib.pyplot as plt

# Generate Data
left_skewed = -np.random.exponential(scale=2, size=1000)

# Plot
plt.figure(figsize=(6, 5))
plt.hist(left_skewed, bins=30)
plt.title("Left-Skewed Distribution")
plt.show()

# %%
#uniform distribution
import numpy as np
import matplotlib.pyplot as plt

# Generate Data
uniform_data = np.random.uniform(low=50, high=90, size=1000)

# Plot
plt.figure(figsize=(6, 5))
plt.hist(uniform_data, bins=30)
plt.title("Uniform Distribution")
plt.show()
